# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go

# %%
df = pd.read_csv("XAUUSD_Candlestick_4_Hour_BID_07.03.2023-07.03.2025.csv")
df
# Out:
#                      Gmt time      Open      High       Low     Close  \
# 0     07.03.2023 00:00:00.000  1846.225  1850.395  1844.045  1847.505
# 1     07.03.2023 04:00:00.000  1847.485  1851.555  1845.275  1848.385
# 2     07.03.2023 08:00:00.000  1848.365  1849.545  1840.855  1841.875
# 3     07.03.2023 12:00:00.000  1841.865  1841.865  1815.555  1817.905
# 4     07.03.2023 16:00:00.000  1817.705  1823.038  1812.655  1813.835
# ...                       ...       ...       ...       ...       ...
# 4386  07.03.2025 00:00:00.000  2910.058  2910.058  2895.698  2905.165
# 4387  07.03.2025 04:00:00.000  2905.149  2917.155  2904.509  2916.985
# 4388  07.03.2025 08:00:00.000  2916.965  2922.875  2915.055  2918.548
# 4389  07.03.2025 12:00:00.000  2918.548  2930.185  2903.229  2915.605
# 4390  07.03.2025 16:00:00.000  2915.545  2919.305  2911.425  2913.795
#
#             Volume
# 0     2.649750e+06
# 1     2.423240e+06
# 2     3.355640e+06
# 3     9.799570e+06
# 4     6.922070e+06
# ...            ...
# 4386  8.180990e+00
# 4387  6.890170e+00
# 4388  8.222425e+00
# 4389  1.348301e+01
# 4390  1.651950e+00
#
# [4391 rows x 6 columns]

# %%
df = df[df["Volume"] != 0]
df.reset_index(drop=True, inplace=True)
df.tail(5)
# Out:
#                      Gmt time      Open      High       Low     Close  \
# 3205  07.03.2025 00:00:00.000  2910.058  2910.058  2895.698  2905.165
# 3206  07.03.2025 04:00:00.000  2905.149  2917.155  2904.509  2916.985
# 3207  07.03.2025 08:00:00.000  2916.965  2922.875  2915.055  2918.548
# 3208  07.03.2025 12:00:00.000  2918.548  2930.185  2903.229  2915.605
# 3209  07.03.2025 16:00:00.000  2915.545  2919.305  2911.425  2913.795
#
#          Volume
# 3205   8.180990
# 3206   6.890170
# 3207   8.222425
# 3208  13.483010
# 3209   1.651950

# %%
dfpl = df[3000:3209]

fig = go.Figure(data=[go.Candlestick(x=dfpl.index,
                                     open=dfpl['Open'],
                                     high=dfpl['High'],
                                     low=dfpl['Low'],
                                     close=dfpl['Close'])])

fig.show()

# %%
data = yf.download(tickers="XAU-USD", period='max', interval='4h')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['XAU-USD']: YFTzMissingError('possibly delisted; no timezone found')
